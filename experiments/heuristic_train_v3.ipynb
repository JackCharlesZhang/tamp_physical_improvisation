# %% [markdown]
# # Custom DQN Training for Distance Heuristic
#
# This notebook tests the custom DQN implementation on a tiny gridworld environment.
#
# ## Goals
# 1. Collect training data (state pairs from planning graph)
# 2. Train distance heuristic using transparent custom DQN
# 3. Evaluate learned distances vs true distances
# 4. Debug any issues with full visibility into training

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Setup

# %%
import sys
import numpy as np
import torch
from pathlib import Path

# Add src to path if needed
sys.path.insert(0, str(Path.cwd().parent / "src"))

from tamp_improv.benchmarks.gridworld import GridworldTAMPSystem
from tamp_improv.approaches.improvisational.base import ImprovisationalTAMPApproach
from tamp_improv.approaches.improvisational.policies.multi_rl import MultiRLPolicy
from tamp_improv.approaches.improvisational.policies.rl import RLConfig
from tamp_improv.approaches.improvisational.collection import collect_total_shortcuts
from tamp_improv.approaches.improvisational.distance_heuristic_v3 import (
    DistanceHeuristicV3,
    DistanceHeuristicV3Config,
)
from tamp_improv.approaches.improvisational.graph_training import compute_graph_distances

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
# Out:
# PyTorch version: 2.9.0+cu128
# CUDA available: False
# Using device: cpu

# %% [markdown]
# ## Configuration

# %% [markdown]
# ## Step 1: Create Gridworld Environment

# %%
# Create tiny gridworld
system = GridworldTAMPSystem.create_default(
    num_cells=2,
    num_states_per_cell=5,
    num_teleporters=0,
    seed=42,
    max_episode_steps=200,
)

print(f"✓ Created GridworldTAMPSystem")
print(f"  System name: {system.name}")
print(f"  Action space: {system.env.action_space}")
print(f"  Observation space: {system.env.observation_space}")
# Out:
# Warning: Action space is not Box, using original action space.
# ✓ Created GridworldTAMPSystem
#   System name: TAMPSystem
#   Action space: Discrete(5)
#   Observation space: Graph(Box(-inf, inf, (6,), float32), None)

# %% [markdown]
# ## Step 2: Collect Training Data
#
# This builds the planning graph and collects state pairs.

# %%
# Create approach for collection
rl_config = RLConfig(device=device)
policy = MultiRLPolicy(seed=42, config=rl_config)
approach = ImprovisationalTAMPApproach(system, policy, seed=42)
approach.training_mode = True

print("✓ Created approach")
# Out:
# ✓ Created approach

# %%
# Collection config
config_dict = {
    "seed": 42,
    "collect_episodes": 5,
    "use_random_rollouts": True,
    "num_rollouts_per_node": 5,
    "max_steps_per_rollout": 100,
    "shortcut_success_threshold": 0.5,
}

# Collect data
print("\nCollecting training data...")
rng = np.random.default_rng(42)
training_data = collect_total_shortcuts(system, approach, config_dict, rng=rng)

print(f"\n✓ Collection complete!")
print(f"  Nodes with states: {len(training_data.node_states)}")
print(f"  Total shortcuts: {len(training_data.valid_shortcuts)}")
print(f"  Planning graph: {len(training_data.graph.nodes)} nodes, {len(training_data.graph.edges)} edges")
# Out:
# Collecting training data...
#
# ================================================================================
# Collecting total planning graph from 5 episodes
# ================================================================================
# Building total planning graph from 5 episodes...
# Planning graph with 5 nodes and 5 edges
#   Step 1/1: 0 -> 1
#   Step 1/1: 0 -> 2
#   Step 1/2: 0 -> 1
#   Step 2/2: 1 -> 3
#   Step 1/3: 0 -> 1
#   Step 2/3: 1 -> 3
#   Step 3/3: 3 -> 4
# Planning graph with 5 nodes and 5 edges
#   Step 1/1: 0 -> 1
#   Step 1/1: 0 -> 2
#   Step 1/2: 0 -> 1
#   Step 2/2: 1 -> 3
#   Step 1/3: 0 -> 1
#   Step 2/3: 1 -> 3
#   Step 3/3: 3 -> 4
# Planning graph with 5 nodes and 5 edges
#   Step 1/1: 0 -> 1
#   Step 1/1: 0 -> 2
#   Step 1/2: 0 -> 1
#   Step 2/2: 1 -> 3
#   Step 1/3: 0 -> 1
#   Step 2/3: 1 -> 3
#   Step 1/3: 0 -> 1
#   Step 2/3: 1 -> 3
#   Step 3/3: 3 -> 4
# Planning graph with 5 nodes and 5 edges
#   Step 1/1: 0 -> 1
#   Step 1/1: 0 -> 2
#   Step 1/2: 0 -> 1
#   Step 2/2: 1 -> 3
#   Step 1/2: 0 -> 1
#   Step 2/2: 1 -> 3
#   Step 1/2: 0 -> 1
#   Step 2/2: 1 -> 3
#   Step 1/3: 0 -> 1
#   Step 2/3: 1 -> 3
#   Step 3/3: 3 -> 4
# Planning graph with 5 nodes and 5 edges
#   Step 1/1: 0 -> 1
#   Step 1/1: 0 -> 2
#   Step 1/2: 0 -> 1
#   Step 2/2: 1 -> 3
#   Step 1/3: 0 -> 1
#   Step 2/3: 1 -> 3
#   Step 3/3: 3 -> 4
#   Episode 5/5: 5 nodes, 5 edges
# Total graph complete: 5 nodes, 5 edges, 25 total states
#
# Node ID -> Atoms mapping:
# ================================================================================
#   Node   0 ( 0 states): (InCol0 robot0), (InRow0 robot0)
#   Node   1 ( 0 states): (InCol0 robot0), (InRow1 robot0)
#   Node   2 ( 0 states): (InCol1 robot0), (InRow0 robot0)
#   Node   3 ( 0 states): (InCol1 robot0), (InRow1 robot0)
#   Node   4 ( 0 states): (GoalReached robot0), (InCol1 robot0), (InRow1 robot0)
# ================================================================================
#
# Computing edge costs using 25 samples per edge...
# Edge cost computation complete!
#
# ================================================================================
# Identifying shortcuts from total graph
# ================================================================================
# Identified 5 shortcut candidates
#
# ================================================================================
# Collection complete: 25 training examples, 25 shortcuts
# ================================================================================
#
# ✓ Collection complete!
#   Nodes with states: 5
#   Total shortcuts: 25
#   Planning graph: 5 nodes, 5 edges

# %% [markdown]
# ## Step 3: Prepare State Pairs for Training

# %%
# Extract state pairs from training data
planning_graph = training_data.graph
all_node_states = training_data.node_states

# Collect all (source_state, target_state) pairs
state_pairs = []
for source_node in planning_graph.nodes:
    for target_node in planning_graph.nodes:
        if source_node.id == target_node.id:
            continue
        
        if source_node.id not in all_node_states or target_node.id not in all_node_states:
            continue
        
        source_states = all_node_states[source_node.id]
        target_states = all_node_states[target_node.id]
        
        if not source_states or not target_states:
            continue
        
        # Take first state from each node (for simplicity)
        # Could also take all combinations: for s in source_states for t in target_states
        for i in range(len(source_states)):
            for j in range(len(target_states)):
                state_pairs.append((source_states[i], target_states[j]))

print(f"\n✓ Prepared {len(state_pairs)} state pairs for training")

# Sample a few pairs to inspect
print("\nSample state pairs:")
for i, (source, target) in enumerate(state_pairs[:3]):
    source_atoms = system.perceiver.step(source)
    target_atoms = system.perceiver.step(target)
    print(f"  Pair {i}: {len(source_atoms)} source atoms -> {len(target_atoms)} target atoms")
# Out:
# ✓ Prepared 500 state pairs for training
#
# Sample state pairs:
#   Pair 0: 2 source atoms -> 2 target atoms
#   Pair 1: 2 source atoms -> 2 target atoms
#   Pair 2: 2 source atoms -> 2 target atoms

# %% [markdown]
# ## Step 4: Train Distance Heuristic with Custom DQN
#
# This is where the magic happens! The custom DQN will print detailed logs showing:
# - Episode statistics (reward, length, success rate)
# - Training metrics (loss, Q-values, TD errors)
# - Replay buffer size
# - Epsilon decay
# - Periodic evaluation

# %%
# Create distance heuristic config with custom DQN enabled
heuristic_config = DistanceHeuristicV3Config(
    latent_dim=4,
    hidden_dims=[64, 64],
    learning_rate=5e-3,
    batch_size=128,  # Smaller batch for tiny dataset
    buffer_size=10000,  # Smaller buffer
    c_target=1,
    gamma=0.9,
    iters_per_epoch=1,
    device='cuda',
    repetition_factor=1,
    policy_temperature=1,
    learn_frequency=1
)

# %%
# Create and train heuristic
heuristic = DistanceHeuristicV3(config=heuristic_config, seed=42)

print("\nStarting training...\n")
heuristic.train(
    env=system.env,
    state_pairs=state_pairs,
    perceiver=system.perceiver,
    num_epochs=300,
    trajectories_per_epoch=10,
    max_episode_steps=50
)

print("\n✓ Training complete!")
# Out:
# Starting training...
#
#
# Training distance heuristic V3 on 500 state pairs...
# Device: cpu
# State dimension: 12
# Latent dimension: 4
# Computed observation statistics: mean=2.323, std=0.694
#
# Starting training for 300 epochs...
# Collecting 10 trajectories per epoch
# Using cosine annealing LR scheduler: 0.005 -> 5e-05
#
# [Epoch 12/300]
#   Buffer size: 130
#   Learning rate: 0.004980
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 5.0047
#   Alignment loss: 0.0017
#   Uniformity loss: 4.8368
#   Accuracy: 53.12%
#   L2 norm: 0.1661
#   Lambda: 1.0000
#
# [Epoch 13/300]
#   Buffer size: 140
#   Learning rate: 0.004977
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.8449
#   Alignment loss: 0.0023
#   Uniformity loss: 4.8353
#   Accuracy: 46.09%
#   L2 norm: 0.0123
#   Lambda: 0.9950
#
# [Epoch 14/300]
#   Buffer size: 150
#   Learning rate: 0.004973
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.8852
#   Alignment loss: 0.0039
#   Uniformity loss: 4.8321
#   Accuracy: 36.72%
#   L2 norm: 0.0587
#   Lambda: 0.9905
#
# [Epoch 15/300]
#   Buffer size: 160
#   Learning rate: 0.004970
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.8726
#   Alignment loss: 0.0039
#   Uniformity loss: 4.8177
#   Accuracy: 40.62%
#   L2 norm: 0.0652
#   Lambda: 0.9859
#
# [Epoch 16/300]
#   Buffer size: 170
#   Learning rate: 0.004965
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.8362
#   Alignment loss: 0.0047
#   Uniformity loss: 4.8125
#   Accuracy: 38.28%
#   L2 norm: 0.0379
#   Lambda: 0.9813
#
# [Epoch 17/300]
#   Buffer size: 180
#   Learning rate: 0.004961
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.8147
#   Alignment loss: 0.0055
#   Uniformity loss: 4.8108
#   Accuracy: 28.91%
#   L2 norm: 0.0221
#   Lambda: 0.9766
#
# [Epoch 18/300]
#   Buffer size: 190
#   Learning rate: 0.004956
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.8016
#   Alignment loss: 0.0098
#   Uniformity loss: 4.7869
#   Accuracy: 19.53%
#   L2 norm: 0.0335
#   Lambda: 0.9718
#
# [Epoch 19/300]
#   Buffer size: 200
#   Learning rate: 0.004951
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.7952
#   Alignment loss: 0.0128
#   Uniformity loss: 4.7679
#   Accuracy: 27.34%
#   L2 norm: 0.0481
#   Lambda: 0.9670
#
# [Epoch 20/300]
#   Buffer size: 210
#   Learning rate: 0.004946
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.7735
#   Alignment loss: 0.0161
#   Uniformity loss: 4.7232
#   Accuracy: 25.00%
#   L2 norm: 0.0728
#   Lambda: 0.9622
#
# [Epoch 21/300]
#   Buffer size: 220
#   Learning rate: 0.004940
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.7562
#   Alignment loss: 0.0241
#   Uniformity loss: 4.6824
#   Accuracy: 27.34%
#   L2 norm: 0.0931
#   Lambda: 0.9574
#
# [Epoch 22/300]
#   Buffer size: 230
#   Learning rate: 0.004935
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 48.4
#   Avg successful length: 25.0
#   --- Training Metrics ---
#   Total loss: 4.7291
#   Alignment loss: 0.0476
#   Uniformity loss: 4.5814
#   Accuracy: 19.53%
#   L2 norm: 0.1484
#   Lambda: 0.9527
#
# [Epoch 23/300]
#   Buffer size: 240
#   Learning rate: 0.004929
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.7262
#   Alignment loss: 0.0634
#   Uniformity loss: 4.5477
#   Accuracy: 15.62%
#   L2 norm: 0.1683
#   Lambda: 0.9479
#
# [Epoch 24/300]
#   Buffer size: 250
#   Learning rate: 0.004922
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.7342
#   Alignment loss: 0.0960
#   Uniformity loss: 4.4773
#   Accuracy: 17.19%
#   L2 norm: 0.2189
#   Lambda: 0.9432
#
# [Epoch 25/300]
#   Buffer size: 260
#   Learning rate: 0.004916
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.7246
#   Alignment loss: 0.1111
#   Uniformity loss: 4.3823
#   Accuracy: 14.84%
#   L2 norm: 0.2942
#   Lambda: 0.9385
#
# [Epoch 26/300]
#   Buffer size: 270
#   Learning rate: 0.004909
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.7280
#   Alignment loss: 0.1141
#   Uniformity loss: 4.3666
#   Accuracy: 19.53%
#   L2 norm: 0.3150
#   Lambda: 0.9339
#
# [Epoch 27/300]
#   Buffer size: 280
#   Learning rate: 0.004902
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.7371
#   Alignment loss: 0.1289
#   Uniformity loss: 4.3711
#   Accuracy: 15.62%
#   L2 norm: 0.3095
#   Lambda: 0.9294
#
# [Epoch 28/300]
#   Buffer size: 290
#   Learning rate: 0.004894
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.6992
#   Alignment loss: 0.1136
#   Uniformity loss: 4.3637
#   Accuracy: 25.00%
#   L2 norm: 0.2989
#   Lambda: 0.9250
#
# [Epoch 29/300]
#   Buffer size: 300
#   Learning rate: 0.004887
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 49.0
#   Avg successful length: 31.0
#   --- Training Metrics ---
#   Total loss: 4.7199
#   Alignment loss: 0.1137
#   Uniformity loss: 4.3689
#   Accuracy: 13.28%
#   L2 norm: 0.3189
#   Lambda: 0.9207
#
# [Epoch 30/300]
#   Buffer size: 310
#   Learning rate: 0.004879
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.6695
#   Alignment loss: 0.0917
#   Uniformity loss: 4.3982
#   Accuracy: 17.97%
#   L2 norm: 0.2659
#   Lambda: 0.9164
#
# [Epoch 31/300]
#   Buffer size: 320
#   Learning rate: 0.004871
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.6743
#   Alignment loss: 0.0810
#   Uniformity loss: 4.4805
#   Accuracy: 21.09%
#   L2 norm: 0.2038
#   Lambda: 0.9122
#
# [Epoch 32/300]
#   Buffer size: 330
#   Learning rate: 0.004862
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 48.2
#   Avg successful length: 23.0
#   --- Training Metrics ---
#   Total loss: 4.6482
#   Alignment loss: 0.0757
#   Uniformity loss: 4.4322
#   Accuracy: 17.19%
#   L2 norm: 0.2357
#   Lambda: 0.9080
#
# [Epoch 33/300]
#   Buffer size: 340
#   Learning rate: 0.004854
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.6819
#   Alignment loss: 0.0878
#   Uniformity loss: 4.4348
#   Accuracy: 18.75%
#   L2 norm: 0.2592
#   Lambda: 0.9038
#
# [Epoch 34/300]
#   Buffer size: 350
#   Learning rate: 0.004845
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 48.8
#   Avg successful length: 29.0
#   --- Training Metrics ---
#   Total loss: 4.6380
#   Alignment loss: 0.0785
#   Uniformity loss: 4.4210
#   Accuracy: 23.44%
#   L2 norm: 0.2429
#   Lambda: 0.8997
#
# [Epoch 35/300]
#   Buffer size: 360
#   Learning rate: 0.004836
#   --- Policy Performance ---
#   Success rate: 20.00% (2/10)
#   Avg trajectory length: 43.8
#   Avg successful length: 15.0
#   --- Training Metrics ---
#   Total loss: 4.5977
#   Alignment loss: 0.0816
#   Uniformity loss: 4.3357
#   Accuracy: 23.44%
#   L2 norm: 0.2890
#   Lambda: 0.8956
#
# [Epoch 36/300]
#   Buffer size: 370
#   Learning rate: 0.004826
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 46.4
#   Avg successful length: 5.0
#   --- Training Metrics ---
#   Total loss: 4.6198
#   Alignment loss: 0.0985
#   Uniformity loss: 4.3573
#   Accuracy: 24.22%
#   L2 norm: 0.2771
#   Lambda: 0.8915
#
# [Epoch 37/300]
#   Buffer size: 380
#   Learning rate: 0.004817
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.5792
#   Alignment loss: 0.1104
#   Uniformity loss: 4.2313
#   Accuracy: 19.53%
#   L2 norm: 0.3545
#   Lambda: 0.8874
#
# [Epoch 38/300]
#   Buffer size: 390
#   Learning rate: 0.004807
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.5764
#   Alignment loss: 0.1332
#   Uniformity loss: 4.1919
#   Accuracy: 21.88%
#   L2 norm: 0.3725
#   Lambda: 0.8834
#
# [Epoch 39/300]
#   Buffer size: 400
#   Learning rate: 0.004796
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 48.4
#   Avg successful length: 25.0
#   --- Training Metrics ---
#   Total loss: 4.5435
#   Alignment loss: 0.1237
#   Uniformity loss: 4.1353
#   Accuracy: 20.31%
#   L2 norm: 0.4097
#   Lambda: 0.8794
#
# [Epoch 40/300]
#   Buffer size: 410
#   Learning rate: 0.004786
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 48.9
#   Avg successful length: 30.0
#   --- Training Metrics ---
#   Total loss: 4.5923
#   Alignment loss: 0.1514
#   Uniformity loss: 4.1664
#   Accuracy: 21.09%
#   L2 norm: 0.4039
#   Lambda: 0.8755
#
# [Epoch 41/300]
#   Buffer size: 420
#   Learning rate: 0.004775
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.5709
#   Alignment loss: 0.1719
#   Uniformity loss: 4.0188
#   Accuracy: 21.88%
#   L2 norm: 0.5128
#   Lambda: 0.8717
#
# [Epoch 42/300]
#   Buffer size: 430
#   Learning rate: 0.004764
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.6111
#   Alignment loss: 0.2404
#   Uniformity loss: 3.8151
#   Accuracy: 21.88%
#   L2 norm: 0.6905
#   Lambda: 0.8680
#
# [Epoch 43/300]
#   Buffer size: 440
#   Learning rate: 0.004753
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.6304
#   Alignment loss: 0.2154
#   Uniformity loss: 3.8466
#   Accuracy: 25.78%
#   L2 norm: 0.7068
#   Lambda: 0.8646
#
# [Epoch 44/300]
#   Buffer size: 450
#   Learning rate: 0.004742
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.5881
#   Alignment loss: 0.2203
#   Uniformity loss: 3.9024
#   Accuracy: 26.56%
#   L2 norm: 0.6083
#   Lambda: 0.8613
#
# [Epoch 45/300]
#   Buffer size: 460
#   Learning rate: 0.004730
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.5608
#   Alignment loss: 0.1903
#   Uniformity loss: 3.9084
#   Accuracy: 25.78%
#   L2 norm: 0.6083
#   Lambda: 0.8582
#
# [Epoch 46/300]
#   Buffer size: 470
#   Learning rate: 0.004718
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.5446
#   Alignment loss: 0.1779
#   Uniformity loss: 3.9669
#   Accuracy: 21.09%
#   L2 norm: 0.5500
#   Lambda: 0.8551
#
# [Epoch 47/300]
#   Buffer size: 480
#   Learning rate: 0.004706
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 49.0
#   Avg successful length: 31.0
#   --- Training Metrics ---
#   Total loss: 4.5712
#   Alignment loss: 0.1836
#   Uniformity loss: 4.0531
#   Accuracy: 21.09%
#   L2 norm: 0.4887
#   Lambda: 0.8520
#
# [Epoch 48/300]
#   Buffer size: 490
#   Learning rate: 0.004694
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 50.7
#   Avg successful length: 48.0
#   --- Training Metrics ---
#   Total loss: 4.5298
#   Alignment loss: 0.1475
#   Uniformity loss: 3.9424
#   Accuracy: 28.91%
#   L2 norm: 0.5961
#   Lambda: 0.8490
#
# [Epoch 49/300]
#   Buffer size: 500
#   Learning rate: 0.004681
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.5752
#   Alignment loss: 0.1867
#   Uniformity loss: 3.9800
#   Accuracy: 19.53%
#   L2 norm: 0.5682
#   Lambda: 0.8460
#
# [Epoch 50/300]
#   Buffer size: 510
#   Learning rate: 0.004668
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 49.4
#   Avg successful length: 35.0
#   --- Training Metrics ---
#   Total loss: 4.5268
#   Alignment loss: 0.1482
#   Uniformity loss: 4.0376
#   Accuracy: 23.44%
#   L2 norm: 0.5047
#   Lambda: 0.8431
#
# [Epoch 51/300]
#   Buffer size: 520
#   Learning rate: 0.004655
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.5331
#   Alignment loss: 0.1562
#   Uniformity loss: 4.0781
#   Accuracy: 23.44%
#   L2 norm: 0.4663
#   Lambda: 0.8402
#
# [Epoch 52/300]
#   Buffer size: 530
#   Learning rate: 0.004642
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.5346
#   Alignment loss: 0.1556
#   Uniformity loss: 4.0858
#   Accuracy: 20.31%
#   L2 norm: 0.4638
#   Lambda: 0.8373
#
# [Epoch 53/300]
#   Buffer size: 540
#   Learning rate: 0.004628
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.5432
#   Alignment loss: 0.1546
#   Uniformity loss: 4.1272
#   Accuracy: 21.09%
#   L2 norm: 0.4357
#   Lambda: 0.8344
#
# [Epoch 54/300]
#   Buffer size: 550
#   Learning rate: 0.004615
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.5128
#   Alignment loss: 0.1179
#   Uniformity loss: 4.1361
#   Accuracy: 30.47%
#   L2 norm: 0.4364
#   Lambda: 0.8314
#
# [Epoch 55/300]
#   Buffer size: 560
#   Learning rate: 0.004601
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.5089
#   Alignment loss: 0.1331
#   Uniformity loss: 4.1080
#   Accuracy: 32.03%
#   L2 norm: 0.4485
#   Lambda: 0.8285
#
# [Epoch 56/300]
#   Buffer size: 570
#   Learning rate: 0.004586
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.5111
#   Alignment loss: 0.1405
#   Uniformity loss: 4.1013
#   Accuracy: 28.91%
#   L2 norm: 0.4532
#   Lambda: 0.8255
#
# [Epoch 57/300]
#   Buffer size: 580
#   Learning rate: 0.004572
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.5340
#   Alignment loss: 0.1448
#   Uniformity loss: 4.1277
#   Accuracy: 29.69%
#   L2 norm: 0.4489
#   Lambda: 0.8225
#
# [Epoch 58/300]
#   Buffer size: 590
#   Learning rate: 0.004557
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.5173
#   Alignment loss: 0.1525
#   Uniformity loss: 4.0901
#   Accuracy: 28.91%
#   L2 norm: 0.4650
#   Lambda: 0.8196
#
# [Epoch 59/300]
#   Buffer size: 600
#   Learning rate: 0.004542
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.4869
#   Alignment loss: 0.1311
#   Uniformity loss: 4.0501
#   Accuracy: 33.59%
#   L2 norm: 0.4986
#   Lambda: 0.8167
#
# [Epoch 60/300]
#   Buffer size: 610
#   Learning rate: 0.004527
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.5681
#   Alignment loss: 0.1582
#   Uniformity loss: 4.0877
#   Accuracy: 21.88%
#   L2 norm: 0.5180
#   Lambda: 0.8138
#
# [Epoch 61/300]
#   Buffer size: 620
#   Learning rate: 0.004512
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 48.9
#   Avg successful length: 30.0
#   --- Training Metrics ---
#   Total loss: 4.5091
#   Alignment loss: 0.1569
#   Uniformity loss: 4.0424
#   Accuracy: 24.22%
#   L2 norm: 0.5089
#   Lambda: 0.8110
#
# [Epoch 62/300]
#   Buffer size: 630
#   Learning rate: 0.004496
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 47.7
#   Avg successful length: 18.0
#   --- Training Metrics ---
#   Total loss: 4.4889
#   Alignment loss: 0.1689
#   Uniformity loss: 3.9625
#   Accuracy: 25.78%
#   L2 norm: 0.5586
#   Lambda: 0.8083
#
# [Epoch 63/300]
#   Buffer size: 640
#   Learning rate: 0.004481
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.4877
#   Alignment loss: 0.1700
#   Uniformity loss: 3.9274
#   Accuracy: 28.91%
#   L2 norm: 0.5936
#   Lambda: 0.8055
#
# [Epoch 64/300]
#   Buffer size: 650
#   Learning rate: 0.004465
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.4696
#   Alignment loss: 0.1573
#   Uniformity loss: 3.8978
#   Accuracy: 35.16%
#   L2 norm: 0.6202
#   Lambda: 0.8028
#
# [Epoch 65/300]
#   Buffer size: 660
#   Learning rate: 0.004448
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.5335
#   Alignment loss: 0.1860
#   Uniformity loss: 4.0554
#   Accuracy: 27.34%
#   L2 norm: 0.5034
#   Lambda: 0.8002
#
# [Epoch 66/300]
#   Buffer size: 670
#   Learning rate: 0.004432
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.4984
#   Alignment loss: 0.1936
#   Uniformity loss: 3.9391
#   Accuracy: 22.66%
#   L2 norm: 0.5781
#   Lambda: 0.7976
#
# [Epoch 67/300]
#   Buffer size: 680
#   Learning rate: 0.004415
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.5070
#   Alignment loss: 0.1776
#   Uniformity loss: 3.9457
#   Accuracy: 27.34%
#   L2 norm: 0.5986
#   Lambda: 0.7950
#
# [Epoch 68/300]
#   Buffer size: 690
#   Learning rate: 0.004399
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.5026
#   Alignment loss: 0.1869
#   Uniformity loss: 3.9502
#   Accuracy: 30.47%
#   L2 norm: 0.5834
#   Lambda: 0.7924
#
# [Epoch 69/300]
#   Buffer size: 700
#   Learning rate: 0.004382
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.4775
#   Alignment loss: 0.1613
#   Uniformity loss: 4.0019
#   Accuracy: 34.38%
#   L2 norm: 0.5363
#   Lambda: 0.7899
#
# [Epoch 70/300]
#   Buffer size: 710
#   Learning rate: 0.004364
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.4997
#   Alignment loss: 0.1884
#   Uniformity loss: 4.0055
#   Accuracy: 28.91%
#   L2 norm: 0.5308
#   Lambda: 0.7873
#
# [Epoch 71/300]
#   Buffer size: 720
#   Learning rate: 0.004347
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.4543
#   Alignment loss: 0.1399
#   Uniformity loss: 3.9469
#   Accuracy: 35.94%
#   L2 norm: 0.5937
#   Lambda: 0.7848
#
# [Epoch 72/300]
#   Buffer size: 730
#   Learning rate: 0.004329
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.4431
#   Alignment loss: 0.1559
#   Uniformity loss: 3.8840
#   Accuracy: 33.59%
#   L2 norm: 0.6313
#   Lambda: 0.7822
#
# [Epoch 73/300]
#   Buffer size: 740
#   Learning rate: 0.004311
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.5065
#   Alignment loss: 0.1766
#   Uniformity loss: 3.9981
#   Accuracy: 32.81%
#   L2 norm: 0.5644
#   Lambda: 0.7798
#
# [Epoch 74/300]
#   Buffer size: 750
#   Learning rate: 0.004293
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 46.6
#   Avg successful length: 7.0
#   --- Training Metrics ---
#   Total loss: 4.4767
#   Alignment loss: 0.1890
#   Uniformity loss: 3.8890
#   Accuracy: 26.56%
#   L2 norm: 0.6320
#   Lambda: 0.7774
#
# [Epoch 75/300]
#   Buffer size: 760
#   Learning rate: 0.004275
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.4669
#   Alignment loss: 0.1660
#   Uniformity loss: 3.9080
#   Accuracy: 39.06%
#   L2 norm: 0.6290
#   Lambda: 0.7750
#
# [Epoch 76/300]
#   Buffer size: 770
#   Learning rate: 0.004257
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.4790
#   Alignment loss: 0.1726
#   Uniformity loss: 3.9487
#   Accuracy: 30.47%
#   L2 norm: 0.5975
#   Lambda: 0.7727
#
# [Epoch 77/300]
#   Buffer size: 780
#   Learning rate: 0.004238
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.4255
#   Alignment loss: 0.1451
#   Uniformity loss: 3.9557
#   Accuracy: 37.50%
#   L2 norm: 0.5679
#   Lambda: 0.7704
#
# [Epoch 78/300]
#   Buffer size: 790
#   Learning rate: 0.004219
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.4301
#   Alignment loss: 0.1402
#   Uniformity loss: 3.9831
#   Accuracy: 43.75%
#   L2 norm: 0.5530
#   Lambda: 0.7681
#
# [Epoch 79/300]
#   Buffer size: 800
#   Learning rate: 0.004200
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.4233
#   Alignment loss: 0.1456
#   Uniformity loss: 3.9247
#   Accuracy: 42.19%
#   L2 norm: 0.6002
#   Lambda: 0.7659
#
# [Epoch 80/300]
#   Buffer size: 810
#   Learning rate: 0.004181
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.4298
#   Alignment loss: 0.1552
#   Uniformity loss: 3.9735
#   Accuracy: 42.97%
#   L2 norm: 0.5522
#   Lambda: 0.7637
#
# [Epoch 81/300]
#   Buffer size: 820
#   Learning rate: 0.004162
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.4335
#   Alignment loss: 0.1688
#   Uniformity loss: 3.9062
#   Accuracy: 35.94%
#   L2 norm: 0.6102
#   Lambda: 0.7616
#
# [Epoch 82/300]
#   Buffer size: 830
#   Learning rate: 0.004142
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 50.3
#   Avg successful length: 44.0
#   --- Training Metrics ---
#   Total loss: 4.3900
#   Alignment loss: 0.1431
#   Uniformity loss: 3.8286
#   Accuracy: 42.19%
#   L2 norm: 0.6702
#   Lambda: 0.7595
#
# [Epoch 83/300]
#   Buffer size: 840
#   Learning rate: 0.004123
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3900
#   Alignment loss: 0.1541
#   Uniformity loss: 3.8633
#   Accuracy: 44.53%
#   L2 norm: 0.6283
#   Lambda: 0.7574
#
# [Epoch 84/300]
#   Buffer size: 850
#   Learning rate: 0.004103
#   --- Policy Performance ---
#   Success rate: 20.00% (2/10)
#   Avg trajectory length: 46.4
#   Avg successful length: 28.0
#   --- Training Metrics ---
#   Total loss: 4.3806
#   Alignment loss: 0.1554
#   Uniformity loss: 3.8276
#   Accuracy: 50.00%
#   L2 norm: 0.6547
#   Lambda: 0.7553
#
# [Epoch 85/300]
#   Buffer size: 860
#   Learning rate: 0.004083
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3673
#   Alignment loss: 0.1424
#   Uniformity loss: 3.8154
#   Accuracy: 49.22%
#   L2 norm: 0.6684
#   Lambda: 0.7533
#
# [Epoch 86/300]
#   Buffer size: 870
#   Learning rate: 0.004062
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 48.3
#   Avg successful length: 24.0
#   --- Training Metrics ---
#   Total loss: 4.3422
#   Alignment loss: 0.1333
#   Uniformity loss: 3.7575
#   Accuracy: 53.12%
#   L2 norm: 0.7109
#   Lambda: 0.7513
#
# [Epoch 87/300]
#   Buffer size: 880
#   Learning rate: 0.004042
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3565
#   Alignment loss: 0.1474
#   Uniformity loss: 3.7872
#   Accuracy: 46.88%
#   L2 norm: 0.6845
#   Lambda: 0.7494
#
# [Epoch 88/300]
#   Buffer size: 890
#   Learning rate: 0.004021
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3411
#   Alignment loss: 0.1624
#   Uniformity loss: 3.6842
#   Accuracy: 56.25%
#   L2 norm: 0.7563
#   Lambda: 0.7475
#
# [Epoch 89/300]
#   Buffer size: 900
#   Learning rate: 0.004001
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3625
#   Alignment loss: 0.1617
#   Uniformity loss: 3.5979
#   Accuracy: 50.00%
#   L2 norm: 0.8625
#   Lambda: 0.7457
#
# [Epoch 90/300]
#   Buffer size: 910
#   Learning rate: 0.003980
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 46.2
#   Avg successful length: 3.0
#   --- Training Metrics ---
#   Total loss: 4.3446
#   Alignment loss: 0.1891
#   Uniformity loss: 3.5348
#   Accuracy: 52.34%
#   L2 norm: 0.8815
#   Lambda: 0.7440
#
# [Epoch 91/300]
#   Buffer size: 920
#   Learning rate: 0.003959
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3518
#   Alignment loss: 0.2063
#   Uniformity loss: 3.4612
#   Accuracy: 53.12%
#   L2 norm: 0.9441
#   Lambda: 0.7424
#
# [Epoch 92/300]
#   Buffer size: 930
#   Learning rate: 0.003938
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3608
#   Alignment loss: 0.1917
#   Uniformity loss: 3.4731
#   Accuracy: 51.56%
#   L2 norm: 0.9568
#   Lambda: 0.7409
#
# [Epoch 93/300]
#   Buffer size: 940
#   Learning rate: 0.003916
#   --- Policy Performance ---
#   Success rate: 30.00% (3/10)
#   Avg trajectory length: 45.5
#   Avg successful length: 32.7
#   --- Training Metrics ---
#   Total loss: 4.3583
#   Alignment loss: 0.2075
#   Uniformity loss: 3.3957
#   Accuracy: 53.12%
#   L2 norm: 1.0149
#   Lambda: 0.7396
#
# [Epoch 94/300]
#   Buffer size: 950
#   Learning rate: 0.003895
#   --- Policy Performance ---
#   Success rate: 20.00% (2/10)
#   Avg trajectory length: 45.3
#   Avg successful length: 22.5
#   --- Training Metrics ---
#   Total loss: 4.4244
#   Alignment loss: 0.2174
#   Uniformity loss: 3.2789
#   Accuracy: 56.25%
#   L2 norm: 1.1821
#   Lambda: 0.7384
#
# [Epoch 95/300]
#   Buffer size: 960
#   Learning rate: 0.003873
#   --- Policy Performance ---
#   Success rate: 20.00% (2/10)
#   Avg trajectory length: 44.0
#   Avg successful length: 16.0
#   --- Training Metrics ---
#   Total loss: 4.3945
#   Alignment loss: 0.2511
#   Uniformity loss: 3.2964
#   Accuracy: 51.56%
#   L2 norm: 1.1051
#   Lambda: 0.7373
#
# [Epoch 96/300]
#   Buffer size: 970
#   Learning rate: 0.003851
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.4307
#   Alignment loss: 0.2645
#   Uniformity loss: 3.2882
#   Accuracy: 44.53%
#   L2 norm: 1.1358
#   Lambda: 0.7365
#
# [Epoch 97/300]
#   Buffer size: 980
#   Learning rate: 0.003829
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3846
#   Alignment loss: 0.2627
#   Uniformity loss: 3.2404
#   Accuracy: 50.00%
#   L2 norm: 1.1398
#   Lambda: 0.7357
#
# [Epoch 98/300]
#   Buffer size: 990
#   Learning rate: 0.003807
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 49.7
#   Avg successful length: 38.0
#   --- Training Metrics ---
#   Total loss: 4.3873
#   Alignment loss: 0.2589
#   Uniformity loss: 3.2929
#   Accuracy: 54.69%
#   L2 norm: 1.0962
#   Lambda: 0.7352
#
# [Epoch 99/300]
#   Buffer size: 1000
#   Learning rate: 0.003785
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3606
#   Alignment loss: 0.2309
#   Uniformity loss: 3.3571
#   Accuracy: 52.34%
#   L2 norm: 1.0364
#   Lambda: 0.7347
#
# [Epoch 100/300]
#   Buffer size: 1010
#   Learning rate: 0.003763
#   --- Policy Performance ---
#   Success rate: 20.00% (2/10)
#   Avg trajectory length: 46.7
#   Avg successful length: 29.5
#   --- Training Metrics ---
#   Total loss: 4.4086
#   Alignment loss: 0.2237
#   Uniformity loss: 3.4400
#   Accuracy: 59.38%
#   L2 norm: 1.0102
#   Lambda: 0.7343
#
# [Epoch 101/300]
#   Buffer size: 1020
#   Learning rate: 0.003740
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3502
#   Alignment loss: 0.2129
#   Uniformity loss: 3.5083
#   Accuracy: 51.56%
#   L2 norm: 0.8994
#   Lambda: 0.7339
#
# [Epoch 102/300]
#   Buffer size: 1030
#   Learning rate: 0.003717
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3808
#   Alignment loss: 0.2214
#   Uniformity loss: 3.4300
#   Accuracy: 49.22%
#   L2 norm: 0.9961
#   Lambda: 0.7336
#
# [Epoch 103/300]
#   Buffer size: 1040
#   Learning rate: 0.003695
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3282
#   Alignment loss: 0.1945
#   Uniformity loss: 3.4078
#   Accuracy: 57.81%
#   L2 norm: 0.9930
#   Lambda: 0.7332
#
# [Epoch 104/300]
#   Buffer size: 1050
#   Learning rate: 0.003672
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3605
#   Alignment loss: 0.1906
#   Uniformity loss: 3.4975
#   Accuracy: 51.56%
#   L2 norm: 0.9421
#   Lambda: 0.7329
#
# [Epoch 105/300]
#   Buffer size: 1060
#   Learning rate: 0.003649
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3188
#   Alignment loss: 0.2043
#   Uniformity loss: 3.5137
#   Accuracy: 55.47%
#   L2 norm: 0.8737
#   Lambda: 0.7326
#
# [Epoch 106/300]
#   Buffer size: 1070
#   Learning rate: 0.003625
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3364
#   Alignment loss: 0.1798
#   Uniformity loss: 3.4412
#   Accuracy: 53.91%
#   L2 norm: 0.9838
#   Lambda: 0.7323
#
# [Epoch 107/300]
#   Buffer size: 1080
#   Learning rate: 0.003602
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 50.6
#   Avg successful length: 47.0
#   --- Training Metrics ---
#   Total loss: 4.3850
#   Alignment loss: 0.2117
#   Uniformity loss: 3.4598
#   Accuracy: 56.25%
#   L2 norm: 0.9823
#   Lambda: 0.7320
#
# [Epoch 108/300]
#   Buffer size: 1090
#   Learning rate: 0.003579
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3263
#   Alignment loss: 0.1838
#   Uniformity loss: 3.4393
#   Accuracy: 58.59%
#   L2 norm: 0.9726
#   Lambda: 0.7317
#
# [Epoch 109/300]
#   Buffer size: 1100
#   Learning rate: 0.003555
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 47.9
#   Avg successful length: 20.0
#   --- Training Metrics ---
#   Total loss: 4.3351
#   Alignment loss: 0.2101
#   Uniformity loss: 3.3258
#   Accuracy: 53.91%
#   L2 norm: 1.0648
#   Lambda: 0.7315
#
# [Epoch 110/300]
#   Buffer size: 1110
#   Learning rate: 0.003532
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3787
#   Alignment loss: 0.2179
#   Uniformity loss: 3.4210
#   Accuracy: 51.56%
#   L2 norm: 1.0082
#   Lambda: 0.7312
#
# [Epoch 111/300]
#   Buffer size: 1120
#   Learning rate: 0.003508
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 47.1
#   Avg successful length: 12.0
#   --- Training Metrics ---
#   Total loss: 4.3703
#   Alignment loss: 0.2250
#   Uniformity loss: 3.4552
#   Accuracy: 50.78%
#   L2 norm: 0.9607
#   Lambda: 0.7311
#
# [Epoch 112/300]
#   Buffer size: 1130
#   Learning rate: 0.003484
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3567
#   Alignment loss: 0.1867
#   Uniformity loss: 3.3863
#   Accuracy: 63.28%
#   L2 norm: 1.0507
#   Lambda: 0.7309
#
# [Epoch 113/300]
#   Buffer size: 1140
#   Learning rate: 0.003460
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3483
#   Alignment loss: 0.2041
#   Uniformity loss: 3.4372
#   Accuracy: 50.00%
#   L2 norm: 0.9773
#   Lambda: 0.7307
#
# [Epoch 114/300]
#   Buffer size: 1150
#   Learning rate: 0.003436
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3315
#   Alignment loss: 0.2028
#   Uniformity loss: 3.4937
#   Accuracy: 52.34%
#   L2 norm: 0.9084
#   Lambda: 0.7306
#
# [Epoch 115/300]
#   Buffer size: 1160
#   Learning rate: 0.003412
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3128
#   Alignment loss: 0.2026
#   Uniformity loss: 3.4337
#   Accuracy: 51.56%
#   L2 norm: 0.9484
#   Lambda: 0.7304
#
# [Epoch 116/300]
#   Buffer size: 1170
#   Learning rate: 0.003388
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 50.0
#   Avg successful length: 41.0
#   --- Training Metrics ---
#   Total loss: 4.3254
#   Alignment loss: 0.1820
#   Uniformity loss: 3.4293
#   Accuracy: 52.34%
#   L2 norm: 0.9846
#   Lambda: 0.7302
#
# [Epoch 117/300]
#   Buffer size: 1180
#   Learning rate: 0.003363
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3598
#   Alignment loss: 0.2249
#   Uniformity loss: 3.4363
#   Accuracy: 51.56%
#   L2 norm: 0.9699
#   Lambda: 0.7300
#
# [Epoch 118/300]
#   Buffer size: 1190
#   Learning rate: 0.003339
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 48.1
#   Avg successful length: 22.0
#   --- Training Metrics ---
#   Total loss: 4.3801
#   Alignment loss: 0.2429
#   Uniformity loss: 3.4595
#   Accuracy: 46.09%
#   L2 norm: 0.9500
#   Lambda: 0.7299
#
# [Epoch 119/300]
#   Buffer size: 1200
#   Learning rate: 0.003314
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3188
#   Alignment loss: 0.2117
#   Uniformity loss: 3.4341
#   Accuracy: 53.12%
#   L2 norm: 0.9457
#   Lambda: 0.7297
#
# [Epoch 120/300]
#   Buffer size: 1210
#   Learning rate: 0.003290
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 48.0
#   Avg successful length: 21.0
#   --- Training Metrics ---
#   Total loss: 4.3481
#   Alignment loss: 0.2156
#   Uniformity loss: 3.5134
#   Accuracy: 46.88%
#   L2 norm: 0.8943
#   Lambda: 0.7295
#
# [Epoch 121/300]
#   Buffer size: 1220
#   Learning rate: 0.003265
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3788
#   Alignment loss: 0.2238
#   Uniformity loss: 3.4945
#   Accuracy: 56.25%
#   L2 norm: 0.9341
#   Lambda: 0.7294
#
# [Epoch 122/300]
#   Buffer size: 1230
#   Learning rate: 0.003240
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 47.4
#   Avg successful length: 15.0
#   --- Training Metrics ---
#   Total loss: 4.3626
#   Alignment loss: 0.2263
#   Uniformity loss: 3.4173
#   Accuracy: 59.38%
#   L2 norm: 0.9902
#   Lambda: 0.7292
#
# [Epoch 123/300]
#   Buffer size: 1240
#   Learning rate: 0.003216
#   --- Policy Performance ---
#   Success rate: 20.00% (2/10)
#   Avg trajectory length: 42.8
#   Avg successful length: 10.0
#   --- Training Metrics ---
#   Total loss: 4.3572
#   Alignment loss: 0.2075
#   Uniformity loss: 3.4977
#   Accuracy: 47.66%
#   L2 norm: 0.9264
#   Lambda: 0.7290
#
# [Epoch 124/300]
#   Buffer size: 1250
#   Learning rate: 0.003191
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.2944
#   Alignment loss: 0.2041
#   Uniformity loss: 3.4185
#   Accuracy: 57.81%
#   L2 norm: 0.9454
#   Lambda: 0.7288
#
# [Epoch 125/300]
#   Buffer size: 1260
#   Learning rate: 0.003166
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 50.0
#   Avg successful length: 41.0
#   --- Training Metrics ---
#   Total loss: 4.3756
#   Alignment loss: 0.2389
#   Uniformity loss: 3.4161
#   Accuracy: 50.00%
#   L2 norm: 0.9923
#   Lambda: 0.7286
#
# [Epoch 126/300]
#   Buffer size: 1270
#   Learning rate: 0.003141
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.4109
#   Alignment loss: 0.2327
#   Uniformity loss: 3.4174
#   Accuracy: 55.47%
#   L2 norm: 1.0309
#   Lambda: 0.7284
#
# [Epoch 127/300]
#   Buffer size: 1280
#   Learning rate: 0.003115
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 48.6
#   Avg successful length: 27.0
#   --- Training Metrics ---
#   Total loss: 4.4042
#   Alignment loss: 0.2318
#   Uniformity loss: 3.3791
#   Accuracy: 50.78%
#   L2 norm: 1.0623
#   Lambda: 0.7283
#
# [Epoch 128/300]
#   Buffer size: 1290
#   Learning rate: 0.003090
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3393
#   Alignment loss: 0.2278
#   Uniformity loss: 3.3926
#   Accuracy: 56.25%
#   L2 norm: 0.9911
#   Lambda: 0.7282
#
# [Epoch 129/300]
#   Buffer size: 1300
#   Learning rate: 0.003065
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3577
#   Alignment loss: 0.2164
#   Uniformity loss: 3.4055
#   Accuracy: 51.56%
#   L2 norm: 1.0074
#   Lambda: 0.7281
#
# [Epoch 130/300]
#   Buffer size: 1310
#   Learning rate: 0.003040
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3408
#   Alignment loss: 0.2141
#   Uniformity loss: 3.3759
#   Accuracy: 53.12%
#   L2 norm: 1.0219
#   Lambda: 0.7280
#
# [Epoch 131/300]
#   Buffer size: 1320
#   Learning rate: 0.003014
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3742
#   Alignment loss: 0.1988
#   Uniformity loss: 3.4029
#   Accuracy: 60.16%
#   L2 norm: 1.0427
#   Lambda: 0.7279
#
# [Epoch 132/300]
#   Buffer size: 1330
#   Learning rate: 0.002989
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 47.3
#   Avg successful length: 14.0
#   --- Training Metrics ---
#   Total loss: 4.3511
#   Alignment loss: 0.2430
#   Uniformity loss: 3.3592
#   Accuracy: 53.12%
#   L2 norm: 1.0201
#   Lambda: 0.7278
#
# [Epoch 133/300]
#   Buffer size: 1340
#   Learning rate: 0.002963
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3203
#   Alignment loss: 0.2067
#   Uniformity loss: 3.3535
#   Accuracy: 59.38%
#   L2 norm: 1.0309
#   Lambda: 0.7278
#
# [Epoch 134/300]
#   Buffer size: 1350
#   Learning rate: 0.002938
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 47.3
#   Avg successful length: 14.0
#   --- Training Metrics ---
#   Total loss: 4.3514
#   Alignment loss: 0.2279
#   Uniformity loss: 3.3713
#   Accuracy: 52.34%
#   L2 norm: 1.0235
#   Lambda: 0.7277
#
# [Epoch 135/300]
#   Buffer size: 1360
#   Learning rate: 0.002912
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 47.3
#   Avg successful length: 14.0
#   --- Training Metrics ---
#   Total loss: 4.4247
#   Alignment loss: 0.2352
#   Uniformity loss: 3.4503
#   Accuracy: 49.22%
#   L2 norm: 1.0109
#   Lambda: 0.7277
#
# [Epoch 136/300]
#   Buffer size: 1370
#   Learning rate: 0.002887
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3870
#   Alignment loss: 0.2570
#   Uniformity loss: 3.3867
#   Accuracy: 51.56%
#   L2 norm: 1.0148
#   Lambda: 0.7277
#
# [Epoch 137/300]
#   Buffer size: 1380
#   Learning rate: 0.002861
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3612
#   Alignment loss: 0.2110
#   Uniformity loss: 3.3436
#   Accuracy: 56.25%
#   L2 norm: 1.0754
#   Lambda: 0.7277
#
# [Epoch 138/300]
#   Buffer size: 1390
#   Learning rate: 0.002835
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3753
#   Alignment loss: 0.2280
#   Uniformity loss: 3.4849
#   Accuracy: 50.00%
#   L2 norm: 0.9375
#   Lambda: 0.7277
#
# [Epoch 139/300]
#   Buffer size: 1400
#   Learning rate: 0.002809
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3225
#   Alignment loss: 0.1824
#   Uniformity loss: 3.4134
#   Accuracy: 54.69%
#   L2 norm: 0.9991
#   Lambda: 0.7277
#
# [Epoch 140/300]
#   Buffer size: 1410
#   Learning rate: 0.002784
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3393
#   Alignment loss: 0.1984
#   Uniformity loss: 3.4405
#   Accuracy: 57.03%
#   L2 norm: 0.9738
#   Lambda: 0.7277
#
# [Epoch 141/300]
#   Buffer size: 1420
#   Learning rate: 0.002758
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 46.9
#   Avg successful length: 10.0
#   --- Training Metrics ---
#   Total loss: 4.3532
#   Alignment loss: 0.2160
#   Uniformity loss: 3.5290
#   Accuracy: 53.12%
#   L2 norm: 0.8857
#   Lambda: 0.7277
#
# [Epoch 142/300]
#   Buffer size: 1430
#   Learning rate: 0.002732
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 48.8
#   Avg successful length: 29.0
#   --- Training Metrics ---
#   Total loss: 4.3076
#   Alignment loss: 0.1868
#   Uniformity loss: 3.4841
#   Accuracy: 54.69%
#   L2 norm: 0.9130
#   Lambda: 0.7277
#
# [Epoch 143/300]
#   Buffer size: 1440
#   Learning rate: 0.002706
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 48.6
#   Avg successful length: 27.0
#   --- Training Metrics ---
#   Total loss: 4.3795
#   Alignment loss: 0.2148
#   Uniformity loss: 3.3955
#   Accuracy: 52.34%
#   L2 norm: 1.0398
#   Lambda: 0.7276
#
# [Epoch 144/300]
#   Buffer size: 1450
#   Learning rate: 0.002680
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3130
#   Alignment loss: 0.1868
#   Uniformity loss: 3.3916
#   Accuracy: 57.03%
#   L2 norm: 1.0068
#   Lambda: 0.7275
#
# [Epoch 145/300]
#   Buffer size: 1460
#   Learning rate: 0.002655
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3721
#   Alignment loss: 0.2102
#   Uniformity loss: 3.3934
#   Accuracy: 50.78%
#   L2 norm: 1.0392
#   Lambda: 0.7275
#
# [Epoch 146/300]
#   Buffer size: 1470
#   Learning rate: 0.002629
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3270
#   Alignment loss: 0.1968
#   Uniformity loss: 3.4850
#   Accuracy: 58.59%
#   L2 norm: 0.9214
#   Lambda: 0.7274
#
# [Epoch 147/300]
#   Buffer size: 1480
#   Learning rate: 0.002603
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3708
#   Alignment loss: 0.2351
#   Uniformity loss: 3.4158
#   Accuracy: 51.56%
#   L2 norm: 0.9929
#   Lambda: 0.7273
#
# [Epoch 148/300]
#   Buffer size: 1490
#   Learning rate: 0.002577
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3215
#   Alignment loss: 0.2026
#   Uniformity loss: 3.4943
#   Accuracy: 54.69%
#   L2 norm: 0.9018
#   Lambda: 0.7273
#
# [Epoch 149/300]
#   Buffer size: 1499
#   Learning rate: 0.002551
#   --- Policy Performance ---
#   Success rate: 30.00% (3/10)
#   Avg trajectory length: 40.2
#   Avg successful length: 15.0
#   --- Training Metrics ---
#   Total loss: 4.3261
#   Alignment loss: 0.1951
#   Uniformity loss: 3.4480
#   Accuracy: 50.78%
#   L2 norm: 0.9577
#   Lambda: 0.7272
#
# [Epoch 150/300]
#   Buffer size: 1509
#   Learning rate: 0.002525
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3417
#   Alignment loss: 0.2039
#   Uniformity loss: 3.4367
#   Accuracy: 60.16%
#   L2 norm: 0.9752
#   Lambda: 0.7271
#
# [Epoch 151/300]
#   Buffer size: 1519
#   Learning rate: 0.002499
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3937
#   Alignment loss: 0.2288
#   Uniformity loss: 3.5706
#   Accuracy: 53.12%
#   L2 norm: 0.8732
#   Lambda: 0.7270
#
# [Epoch 152/300]
#   Buffer size: 1529
#   Learning rate: 0.002473
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3714
#   Alignment loss: 0.2169
#   Uniformity loss: 3.4822
#   Accuracy: 48.44%
#   L2 norm: 0.9479
#   Lambda: 0.7268
#
# [Epoch 153/300]
#   Buffer size: 1539
#   Learning rate: 0.002447
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3457
#   Alignment loss: 0.1967
#   Uniformity loss: 3.4138
#   Accuracy: 63.28%
#   L2 norm: 1.0082
#   Lambda: 0.7267
#
# [Epoch 154/300]
#   Buffer size: 1549
#   Learning rate: 0.002421
#   --- Policy Performance ---
#   Success rate: 30.00% (3/10)
#   Avg trajectory length: 41.7
#   Avg successful length: 20.0
#   --- Training Metrics ---
#   Total loss: 4.3278
#   Alignment loss: 0.2103
#   Uniformity loss: 3.4072
#   Accuracy: 50.78%
#   L2 norm: 0.9844
#   Lambda: 0.7266
#
# [Epoch 155/300]
#   Buffer size: 1559
#   Learning rate: 0.002395
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3411
#   Alignment loss: 0.2070
#   Uniformity loss: 3.4284
#   Accuracy: 53.12%
#   L2 norm: 0.9801
#   Lambda: 0.7265
#
# [Epoch 156/300]
#   Buffer size: 1569
#   Learning rate: 0.002370
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 46.8
#   Avg successful length: 9.0
#   --- Training Metrics ---
#   Total loss: 4.3677
#   Alignment loss: 0.2378
#   Uniformity loss: 3.3680
#   Accuracy: 46.09%
#   L2 norm: 1.0339
#   Lambda: 0.7264
#
# [Epoch 157/300]
#   Buffer size: 1579
#   Learning rate: 0.002344
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 47.3
#   Avg successful length: 14.0
#   --- Training Metrics ---
#   Total loss: 4.3471
#   Alignment loss: 0.2256
#   Uniformity loss: 3.3262
#   Accuracy: 53.91%
#   L2 norm: 1.0660
#   Lambda: 0.7263
#
# [Epoch 158/300]
#   Buffer size: 1589
#   Learning rate: 0.002318
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3579
#   Alignment loss: 0.2333
#   Uniformity loss: 3.3982
#   Accuracy: 44.53%
#   L2 norm: 1.0002
#   Lambda: 0.7262
#
# [Epoch 159/300]
#   Buffer size: 1599
#   Learning rate: 0.002292
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 46.7
#   Avg successful length: 8.0
#   --- Training Metrics ---
#   Total loss: 4.3569
#   Alignment loss: 0.2552
#   Uniformity loss: 3.3205
#   Accuracy: 54.69%
#   L2 norm: 1.0525
#   Lambda: 0.7262
#
# [Epoch 160/300]
#   Buffer size: 1609
#   Learning rate: 0.002266
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3579
#   Alignment loss: 0.2328
#   Uniformity loss: 3.3673
#   Accuracy: 53.12%
#   L2 norm: 1.0303
#   Lambda: 0.7262
#
# [Epoch 161/300]
#   Buffer size: 1618
#   Learning rate: 0.002241
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 46.0
#   Avg successful length: 1.0
#   --- Training Metrics ---
#   Total loss: 4.3632
#   Alignment loss: 0.2180
#   Uniformity loss: 3.4052
#   Accuracy: 50.00%
#   L2 norm: 1.0132
#   Lambda: 0.7262
#
# [Epoch 162/300]
#   Buffer size: 1628
#   Learning rate: 0.002215
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3276
#   Alignment loss: 0.2002
#   Uniformity loss: 3.3958
#   Accuracy: 52.34%
#   L2 norm: 1.0052
#   Lambda: 0.7262
#
# [Epoch 163/300]
#   Buffer size: 1638
#   Learning rate: 0.002189
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3266
#   Alignment loss: 0.2121
#   Uniformity loss: 3.4395
#   Accuracy: 52.34%
#   L2 norm: 0.9511
#   Lambda: 0.7262
#
# [Epoch 164/300]
#   Buffer size: 1648
#   Learning rate: 0.002163
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 48.3
#   Avg successful length: 24.0
#   --- Training Metrics ---
#   Total loss: 4.3183
#   Alignment loss: 0.1888
# ...
#   Avg trajectory length: 47.6
#   Avg successful length: 17.0
#   --- Training Metrics ---
#   Total loss: 4.3379
#   Alignment loss: 0.2121
#   Uniformity loss: 3.4104
#   Accuracy: 54.69%
#   L2 norm: 0.9950
#   Lambda: 0.7206
#
# [Epoch 250/300]
#   Buffer size: 2506
#   Learning rate: 0.000382
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3406
#   Alignment loss: 0.2089
#   Uniformity loss: 3.4224
#   Accuracy: 48.44%
#   L2 norm: 0.9893
#   Lambda: 0.7206
#
# [Epoch 251/300]
#   Buffer size: 2516
#   Learning rate: 0.000369
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 46.9
#   Avg successful length: 10.0
#   --- Training Metrics ---
#   Total loss: 4.3839
#   Alignment loss: 0.2215
#   Uniformity loss: 3.4306
#   Accuracy: 51.56%
#   L2 norm: 1.0106
#   Lambda: 0.7206
#
# [Epoch 252/300]
#   Buffer size: 2526
#   Learning rate: 0.000356
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 47.3
#   Avg successful length: 14.0
#   --- Training Metrics ---
#   Total loss: 4.3669
#   Alignment loss: 0.2312
#   Uniformity loss: 3.3766
#   Accuracy: 48.44%
#   L2 norm: 1.0368
#   Lambda: 0.7205
#
# [Epoch 253/300]
#   Buffer size: 2536
#   Learning rate: 0.000344
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3329
#   Alignment loss: 0.2034
#   Uniformity loss: 3.5313
#   Accuracy: 51.56%
#   L2 norm: 0.8833
#   Lambda: 0.7205
#
# [Epoch 254/300]
#   Buffer size: 2546
#   Learning rate: 0.000332
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3228
#   Alignment loss: 0.2041
#   Uniformity loss: 3.4180
#   Accuracy: 50.00%
#   L2 norm: 0.9811
#   Lambda: 0.7205
#
# [Epoch 255/300]
#   Buffer size: 2556
#   Learning rate: 0.000320
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 46.4
#   Avg successful length: 5.0
#   --- Training Metrics ---
#   Total loss: 4.3133
#   Alignment loss: 0.2016
#   Uniformity loss: 3.3919
#   Accuracy: 60.16%
#   L2 norm: 0.9993
#   Lambda: 0.7205
#
# [Epoch 256/300]
#   Buffer size: 2566
#   Learning rate: 0.000308
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3526
#   Alignment loss: 0.2080
#   Uniformity loss: 3.4309
#   Accuracy: 53.12%
#   L2 norm: 0.9935
#   Lambda: 0.7205
#
# [Epoch 257/300]
#   Buffer size: 2576
#   Learning rate: 0.000297
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 46.7
#   Avg successful length: 8.0
#   --- Training Metrics ---
#   Total loss: 4.3568
#   Alignment loss: 0.2313
#   Uniformity loss: 3.4503
#   Accuracy: 56.25%
#   L2 norm: 0.9569
#   Lambda: 0.7205
#
# [Epoch 258/300]
#   Buffer size: 2586
#   Learning rate: 0.000286
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3522
#   Alignment loss: 0.2212
#   Uniformity loss: 3.4035
#   Accuracy: 52.34%
#   L2 norm: 1.0067
#   Lambda: 0.7205
#
# [Epoch 259/300]
#   Buffer size: 2596
#   Learning rate: 0.000275
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 47.0
#   Avg successful length: 11.0
#   --- Training Metrics ---
#   Total loss: 4.3302
#   Alignment loss: 0.2115
#   Uniformity loss: 3.4179
#   Accuracy: 54.69%
#   L2 norm: 0.9812
#   Lambda: 0.7205
#
# [Epoch 260/300]
#   Buffer size: 2606
#   Learning rate: 0.000264
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3750
#   Alignment loss: 0.2415
#   Uniformity loss: 3.4835
#   Accuracy: 48.44%
#   L2 norm: 0.9328
#   Lambda: 0.7204
#
# [Epoch 261/300]
#   Buffer size: 2616
#   Learning rate: 0.000254
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 46.4
#   Avg successful length: 5.0
#   --- Training Metrics ---
#   Total loss: 4.2876
#   Alignment loss: 0.1874
#   Uniformity loss: 3.4459
#   Accuracy: 59.38%
#   L2 norm: 0.9369
#   Lambda: 0.7204
#
# [Epoch 262/300]
#   Buffer size: 2626
#   Learning rate: 0.000243
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 46.9
#   Avg successful length: 10.0
#   --- Training Metrics ---
#   Total loss: 4.3778
#   Alignment loss: 0.2500
#   Uniformity loss: 3.4470
#   Accuracy: 47.66%
#   L2 norm: 0.9623
#   Lambda: 0.7204
#
# [Epoch 263/300]
#   Buffer size: 2636
#   Learning rate: 0.000233
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 46.5
#   Avg successful length: 6.0
#   --- Training Metrics ---
#   Total loss: 4.3510
#   Alignment loss: 0.2115
#   Uniformity loss: 3.3994
#   Accuracy: 55.47%
#   L2 norm: 1.0187
#   Lambda: 0.7204
#
# [Epoch 264/300]
#   Buffer size: 2646
#   Learning rate: 0.000224
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3532
#   Alignment loss: 0.2432
#   Uniformity loss: 3.4242
#   Accuracy: 49.22%
#   L2 norm: 0.9671
#   Lambda: 0.7204
#
# [Epoch 265/300]
#   Buffer size: 2656
#   Learning rate: 0.000214
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3201
#   Alignment loss: 0.2045
#   Uniformity loss: 3.4996
#   Accuracy: 53.91%
#   L2 norm: 0.9004
#   Lambda: 0.7204
#
# [Epoch 266/300]
#   Buffer size: 2666
#   Learning rate: 0.000205
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3211
#   Alignment loss: 0.2068
#   Uniformity loss: 3.5338
#   Accuracy: 48.44%
#   L2 norm: 0.8666
#   Lambda: 0.7204
#
# [Epoch 267/300]
#   Buffer size: 2676
#   Learning rate: 0.000196
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3274
#   Alignment loss: 0.2220
#   Uniformity loss: 3.3896
#   Accuracy: 51.56%
#   L2 norm: 0.9957
#   Lambda: 0.7203
#
# [Epoch 268/300]
#   Buffer size: 2686
#   Learning rate: 0.000188
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3023
#   Alignment loss: 0.2035
#   Uniformity loss: 3.4222
#   Accuracy: 53.91%
#   L2 norm: 0.9583
#   Lambda: 0.7203
#
# [Epoch 269/300]
#   Buffer size: 2696
#   Learning rate: 0.000179
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3675
#   Alignment loss: 0.2113
#   Uniformity loss: 3.4666
#   Accuracy: 49.22%
#   L2 norm: 0.9707
#   Lambda: 0.7203
#
# [Epoch 270/300]
#   Buffer size: 2706
#   Learning rate: 0.000171
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3045
#   Alignment loss: 0.2077
#   Uniformity loss: 3.4339
#   Accuracy: 49.22%
#   L2 norm: 0.9453
#   Lambda: 0.7203
#
# [Epoch 271/300]
#   Buffer size: 2716
#   Learning rate: 0.000163
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3199
#   Alignment loss: 0.2026
#   Uniformity loss: 3.4291
#   Accuracy: 57.03%
#   L2 norm: 0.9695
#   Lambda: 0.7203
#
# [Epoch 272/300]
#   Buffer size: 2726
#   Learning rate: 0.000156
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 47.0
#   Avg successful length: 11.0
#   --- Training Metrics ---
#   Total loss: 4.3232
#   Alignment loss: 0.2176
#   Uniformity loss: 3.4944
#   Accuracy: 56.25%
#   L2 norm: 0.8961
#   Lambda: 0.7203
#
# [Epoch 273/300]
#   Buffer size: 2736
#   Learning rate: 0.000148
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 47.0
#   Avg successful length: 11.0
#   --- Training Metrics ---
#   Total loss: 4.3182
#   Alignment loss: 0.1975
#   Uniformity loss: 3.3961
#   Accuracy: 59.38%
#   L2 norm: 1.0041
#   Lambda: 0.7202
#
# [Epoch 274/300]
#   Buffer size: 2746
#   Learning rate: 0.000141
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3095
#   Alignment loss: 0.2030
#   Uniformity loss: 3.4551
#   Accuracy: 59.38%
#   L2 norm: 0.9343
#   Lambda: 0.7202
#
# [Epoch 275/300]
#   Buffer size: 2756
#   Learning rate: 0.000134
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3053
#   Alignment loss: 0.1937
#   Uniformity loss: 3.4075
#   Accuracy: 56.25%
#   L2 norm: 0.9846
#   Lambda: 0.7202
#
# [Epoch 276/300]
#   Buffer size: 2766
#   Learning rate: 0.000128
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 46.2
#   Avg successful length: 3.0
#   --- Training Metrics ---
#   Total loss: 4.3142
#   Alignment loss: 0.2054
#   Uniformity loss: 3.3780
#   Accuracy: 54.69%
#   L2 norm: 1.0101
#   Lambda: 0.7202
#
# [Epoch 277/300]
#   Buffer size: 2776
#   Learning rate: 0.000121
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 47.4
#   Avg successful length: 15.0
#   --- Training Metrics ---
#   Total loss: 4.3334
#   Alignment loss: 0.2059
#   Uniformity loss: 3.4555
#   Accuracy: 49.22%
#   L2 norm: 0.9540
#   Lambda: 0.7202
#
# [Epoch 278/300]
#   Buffer size: 2786
#   Learning rate: 0.000115
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3667
#   Alignment loss: 0.2389
#   Uniformity loss: 3.4122
#   Accuracy: 53.91%
#   L2 norm: 0.9957
#   Lambda: 0.7202
#
# [Epoch 279/300]
#   Buffer size: 2796
#   Learning rate: 0.000110
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3349
#   Alignment loss: 0.1993
#   Uniformity loss: 3.3822
#   Accuracy: 59.38%
#   L2 norm: 1.0317
#   Lambda: 0.7202
#
# [Epoch 280/300]
#   Buffer size: 2806
#   Learning rate: 0.000104
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3373
#   Alignment loss: 0.2349
#   Uniformity loss: 3.4335
#   Accuracy: 52.34%
#   L2 norm: 0.9512
#   Lambda: 0.7202
#
# [Epoch 281/300]
#   Buffer size: 2816
#   Learning rate: 0.000099
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3467
#   Alignment loss: 0.1957
#   Uniformity loss: 3.3809
#   Accuracy: 56.25%
#   L2 norm: 1.0477
#   Lambda: 0.7201
#
# [Epoch 282/300]
#   Buffer size: 2826
#   Learning rate: 0.000094
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3472
#   Alignment loss: 0.2298
#   Uniformity loss: 3.5012
#   Accuracy: 44.53%
#   L2 norm: 0.9008
#   Lambda: 0.7201
#
# [Epoch 283/300]
#   Buffer size: 2836
#   Learning rate: 0.000089
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3434
#   Alignment loss: 0.2334
#   Uniformity loss: 3.4143
#   Accuracy: 54.69%
#   L2 norm: 0.9767
#   Lambda: 0.7201
#
# [Epoch 284/300]
#   Buffer size: 2846
#   Learning rate: 0.000085
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3436
#   Alignment loss: 0.2122
#   Uniformity loss: 3.4804
#   Accuracy: 54.69%
#   L2 norm: 0.9341
#   Lambda: 0.7201
#
# [Epoch 285/300]
#   Buffer size: 2856
#   Learning rate: 0.000080
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 47.0
#   Avg successful length: 11.0
#   --- Training Metrics ---
#   Total loss: 4.3180
#   Alignment loss: 0.2023
#   Uniformity loss: 3.4586
#   Accuracy: 63.28%
#   L2 norm: 0.9399
#   Lambda: 0.7201
#
# [Epoch 286/300]
#   Buffer size: 2866
#   Learning rate: 0.000077
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3664
#   Alignment loss: 0.2377
#   Uniformity loss: 3.4153
#   Accuracy: 54.69%
#   L2 norm: 0.9936
#   Lambda: 0.7201
#
# [Epoch 287/300]
#   Buffer size: 2876
#   Learning rate: 0.000073
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3336
#   Alignment loss: 0.2023
#   Uniformity loss: 3.4341
#   Accuracy: 55.47%
#   L2 norm: 0.9782
#   Lambda: 0.7201
#
# [Epoch 288/300]
#   Buffer size: 2886
#   Learning rate: 0.000070
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3027
#   Alignment loss: 0.2009
#   Uniformity loss: 3.4271
#   Accuracy: 57.03%
#   L2 norm: 0.9568
#   Lambda: 0.7201
#
# [Epoch 289/300]
#   Buffer size: 2896
#   Learning rate: 0.000066
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 47.0
#   Avg successful length: 11.0
#   --- Training Metrics ---
#   Total loss: 4.3614
#   Alignment loss: 0.2293
#   Uniformity loss: 3.4450
#   Accuracy: 52.34%
#   L2 norm: 0.9686
#   Lambda: 0.7201
#
# [Epoch 290/300]
#   Buffer size: 2906
#   Learning rate: 0.000064
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3602
#   Alignment loss: 0.2310
#   Uniformity loss: 3.4285
#   Accuracy: 55.47%
#   L2 norm: 0.9815
#   Lambda: 0.7201
#
# [Epoch 291/300]
#   Buffer size: 2916
#   Learning rate: 0.000061
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3670
#   Alignment loss: 0.2382
#   Uniformity loss: 3.4597
#   Accuracy: 53.91%
#   L2 norm: 0.9514
#   Lambda: 0.7201
#
# [Epoch 292/300]
#   Buffer size: 2926
#   Learning rate: 0.000059
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3505
#   Alignment loss: 0.2373
#   Uniformity loss: 3.4450
#   Accuracy: 48.44%
#   L2 norm: 0.9505
#   Lambda: 0.7201
#
# [Epoch 293/300]
#   Buffer size: 2936
#   Learning rate: 0.000057
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3435
#   Alignment loss: 0.2143
#   Uniformity loss: 3.4456
#   Accuracy: 50.78%
#   L2 norm: 0.9652
#   Lambda: 0.7201
#
# [Epoch 294/300]
#   Buffer size: 2946
#   Learning rate: 0.000055
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 46.8
#   Avg successful length: 9.0
#   --- Training Metrics ---
#   Total loss: 4.3391
#   Alignment loss: 0.2231
#   Uniformity loss: 3.4487
#   Accuracy: 46.88%
#   L2 norm: 0.9496
#   Lambda: 0.7201
#
# [Epoch 295/300]
#   Buffer size: 2956
#   Learning rate: 0.000053
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.2982
#   Alignment loss: 0.1948
#   Uniformity loss: 3.4312
#   Accuracy: 58.59%
#   L2 norm: 0.9544
#   Lambda: 0.7201
#
# [Epoch 296/300]
#   Buffer size: 2966
#   Learning rate: 0.000052
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 46.5
#   Avg successful length: 6.0
#   --- Training Metrics ---
#   Total loss: 4.3407
#   Alignment loss: 0.2244
#   Uniformity loss: 3.4631
#   Accuracy: 49.22%
#   L2 norm: 0.9361
#   Lambda: 0.7201
#
# [Epoch 297/300]
#   Buffer size: 2976
#   Learning rate: 0.000051
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3130
#   Alignment loss: 0.2001
#   Uniformity loss: 3.4495
#   Accuracy: 54.69%
#   L2 norm: 0.9460
#   Lambda: 0.7201
#
# [Epoch 298/300]
#   Buffer size: 2986
#   Learning rate: 0.000051
#   --- Policy Performance ---
#   Success rate: 10.00% (1/10)
#   Avg trajectory length: 46.5
#   Avg successful length: 6.0
#   --- Training Metrics ---
#   Total loss: 4.3413
#   Alignment loss: 0.2167
#   Uniformity loss: 3.4662
#   Accuracy: 53.91%
#   L2 norm: 0.9412
#   Lambda: 0.7200
#
# [Epoch 299/300]
#   Buffer size: 2996
#   Learning rate: 0.000050
#   --- Policy Performance ---
#   Success rate: 0.00% (0/10)
#   Avg trajectory length: 51.0
#   --- Training Metrics ---
#   Total loss: 4.3514
#   Alignment loss: 0.2179
#   Uniformity loss: 3.3898
#   Accuracy: 57.81%
#   L2 norm: 1.0225
#   Lambda: 0.7200
#
# Training complete!
#
# ✓ Training complete!

# %%
heuristic.collect_trajectories(env, )

# %%
heuristic.replay_buffer.trajectories[-1]
# Out:
# [array([0., 5., 0., 1., 0., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 5., 1., 1., 0., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 5., 2., 1., 0., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 5., 3., 1., 0., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 5., 4., 1., 0., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 6., 4., 1., 0., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 7., 4., 1., 0., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 4., 1., 0., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 5., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 5., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 5., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 6., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 5., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 5., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 5., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 6., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 6., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 6., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 5., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 6., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 9., 6., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 6., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 5., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 5., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 6., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 5., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 5., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 5., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 5., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 5., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 5., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 5., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 6., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 5., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 5., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 6., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 5., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 6., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 5., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 6., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 5., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 6., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 5., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 6., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 6., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 6., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 6., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 6., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 6., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 6., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  array([0., 8., 5., 1., 1., 0., 1., 9., 7., 1., 1., 1.], dtype=float32)]

# %%
heuristic.replay_buffer.trajectory_metadata[-1]
# Out:
# {'start_state': array([0., 5., 0., 1., 0., 0., 1., 9., 7., 1., 1., 1.], dtype=float32),
#  'goal_state': array([0., 9., 6., 1., 1., 0., 1., 9., 6., 1., 1., 1.], dtype=float32)}

# %%
encodings = []
for s, g in state_pairs:
    encodings.append(heuristic.s_encode(s))

# %%
print(np.array(encodings).std(axis=0))
# Out:
# [1.3767556 1.0953312 1.1957561 1.1943041]

# %% [markdown]
# ## Step 5: Evaluate Distance Heuristic
#
# Compare learned distances f(s,s') with:
# 1. True optimal distances (from rollouts)
# 2. Graph distances (from planning graph)

# %%
# Compute graph distances
print("Computing graph distances...")
graph_distances = compute_graph_distances(planning_graph, exclude_shortcuts=True)
print(f"✓ Computed {len(graph_distances)} pairwise distances")
# Out:
# Computing graph distances...
# ✓ Computed 46 pairwise distances

# %%
a, b = state_pairs[350]
d_sg = heuristic.latent_dist(a, b)
d_gg = heuristic.latent_dist(b, b)
print(np.sqrt(1 / (2 * np.log(heuristic.config.gamma)) * (d_gg**2 - d_sg**2)))
# Out:
# 8.175434184641874

# %%
heuristic.estimate_distance(a, b)
# Out:
# 16.35086836928375

# %%
heuristic._flatten_state(a)
# Out:
# array([10.,  0.], dtype=float32)

# %%
heuristic._flatten_state(b)
# Out:
# array([20., 10.], dtype=float32)

# %%
from tamp_improv.approaches.improvisational.analyze import compute_true_distance


compute_true_distance(system, a, system.perceiver.step(b))
# Out:
# 0.0

# %%
# Evaluate on all state pairs
import random

print("\nEvaluating learned distances...")
results = []

sampled_state_pairs = [random.choice(state_pairs) for i in range(100)]
for i, (source_state, target_state) in enumerate(sampled_state_pairs):
    # Get learned distance
    learned_dist = heuristic.estimate_distance(source_state, target_state) / 2
    
    # Get true distance (from rollouts)
    target_atoms = system.perceiver.step(target_state)
    true_dist = compute_true_distance(system, source_state, target_atoms)
    
    # Get graph distance (approximation)
    # Find which nodes these states belong to
    source_atoms = system.perceiver.step(source_state)
    source_node_id = None
    target_node_id = None
    
    for node in planning_graph.nodes:
        if node.atoms == source_atoms:
            source_node_id = node.id
        if node.atoms == target_atoms:
            target_node_id = node.id
    
    if source_node_id is not None and target_node_id is not None:
        graph_dist = graph_distances.get((source_node_id, target_node_id), float('inf'))
    else:
        graph_dist = float('inf')
    
    results.append({
        'source_idx': i,
        'learned_distance': learned_dist,
        'true_distance': true_dist,
        'graph_distance': graph_dist,
    })
    
    if (i + 1) % 10 == 0:
        print(f"  Evaluated {i + 1}/{len(state_pairs)} pairs...")

print(f"\n✓ Evaluated {len(results)} state pairs")
# Out:
# Evaluating learned distances...
#   Evaluated 10/2072 pairs...
#   Evaluated 20/2072 pairs...
#   Evaluated 30/2072 pairs...
#   Evaluated 40/2072 pairs...
#   Evaluated 50/2072 pairs...
#   Evaluated 60/2072 pairs...
#   Evaluated 70/2072 pairs...
#   Evaluated 80/2072 pairs...
#   Evaluated 90/2072 pairs...
#   Evaluated 100/2072 pairs...
#
# ✓ Evaluated 100 state pairs

# %% [markdown]
# ## Step 6: Analyze Results

# %%
# Filter finite results
finite_results = [r for r in results if r['graph_distance'] != float('inf')]
infinite_results = [r for r in results if r['graph_distance'] == float('inf')]

print(f"\nResults Summary:")
print(f"  Total pairs: {len(results)}")
print(f"  Finite distance pairs: {len(finite_results)}")
print(f"  Infinite distance pairs: {len(infinite_results)}")
# Out:
# Results Summary:
#   Total pairs: 100
#   Finite distance pairs: 42
#   Infinite distance pairs: 58

# %%
# Compute statistics for finite distance pairs
if finite_results:
    true_dists = np.array([r['true_distance'] for r in finite_results])
    learned_dists = np.array([r['learned_distance'] for r in finite_results])
    graph_dists = np.array([r['graph_distance'] for r in finite_results])
    
    # vs True distance
    mae_true = np.mean(np.abs(true_dists - learned_dists))
    rmse_true = np.sqrt(np.mean((true_dists - learned_dists) ** 2))
    correlation_true = np.corrcoef(true_dists, learned_dists)[0, 1]
    
    # vs Graph distance
    mae_graph = np.mean(np.abs(graph_dists - learned_dists))
    correlation_graph = np.corrcoef(graph_dists, learned_dists)[0, 1]
    
    print(f"\nStatistics (vs True Distance):")
    print(f"  MAE: {mae_true:.2f}")
    print(f"  RMSE: {rmse_true:.2f}")
    print(f"  Correlation: {correlation_true:.3f}")
    
    print(f"\nStatistics (vs Graph Distance):")
    print(f"  MAE: {mae_graph:.2f}")
    print(f"  Correlation: {correlation_graph:.3f}")
    
    print(f"\nDistance Ranges:")
    print(f"  True:    [{true_dists.min():.1f}, {true_dists.max():.1f}]")
    print(f"  Graph:   [{graph_dists.min():.1f}, {graph_dists.max():.1f}]")
    print(f"  Learned: [{learned_dists.min():.1f}, {learned_dists.max():.1f}]")
else:
    print("\nNo finite distance pairs to analyze!")
# Out:
# Statistics (vs True Distance):
#   MAE: 10.60
#   RMSE: 13.90
#   Correlation: 0.692
#
# Statistics (vs Graph Distance):
#   MAE: 9.95
#   Correlation: 0.636
#
# Distance Ranges:
#   True:    [1.0, 47.0]
#   Graph:   [2.6, 37.0]
#   Learned: [1.0, 12.2]

# %%
# Show sample comparisons
if finite_results:
    print("\nSample Comparisons (sorted by true distance):")
    print(f"{'Idx':>4} | {'True':>6} | {'Graph':>6} | {'Learned':>8} | {'Error':>6}")
    print("-" * 45)
    
    sorted_results = sorted(finite_results, key=lambda r: r['true_distance'])
    for r in sorted_results:  # Show first 20
        error = abs(r['true_distance'] - r['learned_distance'])
        print(
            f"{r['source_idx']:>4} | "
            f"{r['true_distance']:>6.1f} | "
            f"{r['graph_distance']:>6.1f} | "
            f"{r['learned_distance']:>8.1f} | "
            f"{error:>6.1f}"
        )
# Out:
# Sample Comparisons (sorted by true distance):
#  Idx |   True |  Graph |  Learned |  Error
# ---------------------------------------------
#   46 |    1.0 |    3.8 |      1.0 |    0.0
#   39 |    3.0 |    2.6 |      2.9 |    0.1
#   95 |    4.0 |    6.2 |      5.6 |    1.6
#    3 |    7.0 |    8.0 |      5.3 |    1.7
#    7 |    7.0 |    6.4 |      4.9 |    2.1
#   35 |    7.0 |    8.0 |      2.3 |    4.7
#   52 |    9.0 |    5.6 |      7.9 |    1.1
#    6 |   10.0 |   10.0 |      5.8 |    4.2
#   26 |   10.0 |   10.0 |      7.9 |    2.1
#   34 |   10.0 |   10.0 |      7.5 |    2.5
#   44 |   10.0 |   10.0 |      7.5 |    2.5
#   50 |   10.0 |   10.0 |      5.8 |    4.2
#   69 |   11.0 |   12.6 |      6.4 |    4.6
#   71 |   11.0 |   12.6 |      7.5 |    3.5
#   81 |   11.0 |   16.4 |      7.6 |    3.4
#   92 |   11.0 |   12.6 |      7.5 |    3.5
#   49 |   13.0 |   16.8 |      7.9 |    5.1
#   72 |   14.0 |   16.2 |      8.0 |    6.0
#   97 |   14.0 |   16.8 |      7.9 |    6.1
#   82 |   15.0 |   13.8 |      7.7 |    7.3
#   83 |   15.0 |   16.2 |      8.6 |    6.4
#   37 |   16.0 |   18.0 |      7.5 |    8.5
#   29 |   18.0 |   15.6 |      7.7 |   10.3
#   14 |   19.0 |   16.4 |     10.6 |    8.4
#   59 |   19.0 |   21.8 |      7.2 |   11.8
#   68 |   19.0 |   18.0 |      9.7 |    9.3
#   66 |   20.0 |   20.0 |      5.1 |   14.9
#   93 |   21.0 |   28.0 |      5.7 |   15.3
#   18 |   22.0 |   23.6 |      8.1 |   13.9
#   30 |   22.0 |   18.0 |      7.9 |   14.1
#   90 |   22.0 |   18.0 |      9.7 |   12.3
#   22 |   24.0 |   22.6 |      7.4 |   16.6
#   28 |   24.0 |   23.6 |      7.9 |   16.1
#   62 |   24.0 |   22.6 |      7.4 |   16.6
#   77 |   26.0 |   19.0 |     10.6 |   15.4
#   88 |   27.0 |   21.8 |      8.7 |   18.3
#   85 |   33.0 |   28.0 |      7.0 |   26.0
#   11 |   36.0 |   29.0 |      9.9 |   26.1
#   25 |   37.0 |   31.8 |     10.0 |   27.0
#   80 |   37.0 |   30.6 |      7.8 |   29.2
#   57 |   38.0 |   37.0 |     10.2 |   27.8
#   48 |   47.0 |   37.0 |     12.2 |   34.8

# %%
sampled_state_pairs[68]
# Out:
# (GraphInstance(nodes=array([[0., 5., 1., 1., 0., 0.],
#         [1., 5., 5., 1., 1., 1.]], dtype=float32), edges=None, edge_links=None),
#  GraphInstance(nodes=array([[0., 5., 9., 1., 1., 0.],
#         [1., 5., 9., 1., 1., 1.]], dtype=float32), edges=None, edge_links=None))

# %% [markdown]
# ## Step 7: Visualize Results

# %%
import matplotlib.pyplot as plt

if finite_results:
    true_dists = np.array([r['true_distance'] for r in finite_results])
    learned_dists = np.array([r['learned_distance'] for r in finite_results])
    
    plt.figure(figsize=(10, 5))
    
    # Scatter plot
    plt.subplot(1, 2, 1)
    plt.scatter(true_dists, learned_dists, alpha=0.6)
    plt.plot([true_dists.min(), true_dists.max()], 
             [true_dists.min(), true_dists.max()], 
             'r--', label='Perfect correlation')
    plt.xlabel('True Distance')
    plt.ylabel('Learned Distance')
    plt.title(f'Learned vs True Distance\n(Correlation: {correlation_true:.3f})')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # Error distribution
    plt.subplot(1, 2, 2)
    errors = true_dists - learned_dists
    plt.hist(errors, bins=20, alpha=0.7, edgecolor='black')
    plt.xlabel('Error (True - Learned)')
    plt.ylabel('Count')
    plt.title(f'Error Distribution\n(MAE: {mae_true:.2f}, RMSE: {rmse_true:.2f})')
    plt.axvline(0, color='r', linestyle='--', label='Zero error')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()
else:
    print("No results to visualize!")

# %% [markdown]
# ## Step 8: Save Heuristic (Optional)

# %%
# Save trained heuristic
save_path = Path.cwd() / "outputs" / "custom_dqn_test"
save_path.mkdir(parents=True, exist_ok=True)

heuristic.save(str(save_path / "distance_heuristic"))
print(f"\n✓ Saved heuristic to {save_path}")

# %% [markdown]
# ## Next Steps
#
# ### If the heuristic is learning well:
# - Increase training steps
# - Try larger environments (more cells, more teleporters)
# - Test on real benchmarks (obstacle2d, tower, etc.)
#
# ### If the heuristic is not learning:
# - Check the training logs above - are Q-values decreasing?
# - Check success rate - is it improving over time?
# - Try different hyperparameters:
#   - Increase `custom_dqn_her_k` (more hindsight goals)
#   - Decrease `learning_starts` (start learning sooner)
#   - Increase `buffer_size` (more experience)
#   - Adjust `custom_dqn_target_update_freq`
# - Check state pairs - are they feasible?
# - Add more logging in custom_dqn.py to debug specific issues
