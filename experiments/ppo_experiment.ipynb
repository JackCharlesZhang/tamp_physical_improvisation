# %%
import gymnasium as gym
import numpy as np
from gymnasium import spaces

class SimpleGrid(gym.Env):
    metadata = {"render.modes": []}

    def __init__(self, size=11, start=(0, 0), goal=(5, 5), max_steps=50):
        super().__init__()
        self.size = size
        self.start = np.array(start)
        self.goal = np.array(goal)
        self.max_steps = max_steps

        self.action_space = spaces.Discrete(4)
        self.observation_space = spaces.Box(
            low=0, high=size - 1, shape=(2,), dtype=np.int32
        )

        self.reset()

    def reset(self, seed=seed):
        self.pos = self.start.copy()
        self.steps = 0
        return self.pos.copy()

    def step(self, action):
        self.steps += 1

        if action == 0:   # up
            self.pos[1] += 1
        elif action == 1: # down
            self.pos[1] -= 1
        elif action == 2: # right
            self.pos[0] += 1
        elif action == 3: # left
            self.pos[0] -= 1

        self.pos = np.clip(self.pos, 0, self.size - 1)

        done = False
        reward = 0.0

        if np.array_equal(self.pos, self.goal):
            reward = 1.0
            done = True
        elif self.steps >= self.max_steps:
            done = True

        return self.pos.copy(), reward, done, {}

# %%
def random_rollout_success(env, n_rollouts=1000):
    successes = 0
    for _ in range(n_rollouts):
        obs = env.reset()
        done = False
        while not done:
            action = env.action_space.sample()
            obs, reward, done, _ = env.step(action)
            if reward > 0:
                successes += 1
                break
    return successes / n_rollouts

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env

def ppo_success_probability(
    env_fn,
    n_seeds=10,
    train_steps=50_000,
    eval_episodes=5
):
    successes = 0

    for seed in range(n_seeds):
        env = make_vec_env(env_fn, n_envs=1, seed=seed)

        model = PPO(
            "MlpPolicy",
            env,
            seed=seed,
            verbose=0,
            gamma=0.99,
            n_steps=128,
            ent_coef=0.0
        )

        model.learn(total_timesteps=train_steps)

        # Deterministic evaluation
        eval_env = env_fn()
        success = False
        for _ in range(eval_episodes):
            obs = eval_env.reset()
            done = False
            while not done:
                action, _ = model.predict(obs, deterministic=True)
                obs, reward, done, _ = eval_env.step(action)
                if reward > 0:
                    success = True
                    break

        if success:
            successes += 1

    return successes / n_seeds

# %%
import matplotlib.pyplot as plt

def run_experiment():
    k = 30
    grid_size = 21
    start = (10, 10)

    distances = [2, 4, 6, 8, 10]

    R_vals = []
    P_vals = []

    for d in distances:
        goal = (10 + d, 10)

        def env_fn():
            return SimpleGrid(
                size=grid_size,
                start=start,
                goal=goal,
                max_steps=k
            )

        env = env_fn()

        R = random_rollout_success(env, n_rollouts=2000)
        P = ppo_success_probability(env_fn, n_seeds=10)

        R_vals.append(R)
        P_vals.append(P)

        print(f"d={d}: R={R:.4f}, P={P:.4f}")

    plt.scatter(R_vals, P_vals)
    plt.xlabel("R(s, g): Random rollout success")
    plt.ylabel("P(s, g): PPO convergence probability")
    plt.title("PPO vs Random Exploration")
    plt.grid(True)
    plt.show()

run_experiment()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 41
#      38     plt.grid(True)
#      39     plt.show()
# ---> 41 run_experiment()
#
# Cell In[10], line 27, in run_experiment()
#      24 env = env_fn()
#      26 R = random_rollout_success(env, n_rollouts=2000)
# ---> 27 P = ppo_success_probability(env_fn, n_seeds=10)
#      29 R_vals.append(R)
#      30 P_vals.append(P)
#
# Cell In[9], line 25, in ppo_success_probability(env_fn, n_seeds, train_steps, eval_episodes)
#      13 env = make_vec_env(env_fn, n_envs=1, seed=seed)
#      15 model = PPO(
#      16     "MlpPolicy",
#      17     env,
#    (...)     22     ent_coef=0.0
#      23 )
# ---> 25 model.learn(total_timesteps=train_steps)
#      27 # Deterministic evaluation
#      28 eval_env = env_fn()
#
# File ~/miniconda3/envs/slap_env/lib/python3.11/site-packages/stable_baselines3/ppo/ppo.py:311, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     302 def learn(
#     303     self: SelfPPO,
#     304     total_timesteps: int,
#    (...)    309     progress_bar: bool = False,
#     310 ) -> SelfPPO:
# --> 311     return super().learn(
#     312         total_timesteps=total_timesteps,
#     313         callback=callback,
#     314         log_interval=log_interval,
#     315         tb_log_name=tb_log_name,
#     316         reset_num_timesteps=reset_num_timesteps,
#     317         progress_bar=progress_bar,
#     318     )
#
# File ~/miniconda3/envs/slap_env/lib/python3.11/site-packages/stable_baselines3/common/on_policy_algorithm.py:310, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     299 def learn(
#     300     self: SelfOnPolicyAlgorithm,
#     301     total_timesteps: int,
#    (...)    306     progress_bar: bool = False,
#     307 ) -> SelfOnPolicyAlgorithm:
#     308     iteration = 0
# --> 310     total_timesteps, callback = self._setup_learn(
#     311         total_timesteps,
#     312         callback,
#     313         reset_num_timesteps,
#     314         tb_log_name,
#     315         progress_bar,
#     316     )
#     318     callback.on_training_start(locals(), globals())
#     320     assert self.env is not None
#
# File ~/miniconda3/envs/slap_env/lib/python3.11/site-packages/stable_baselines3/common/base_class.py:423, in BaseAlgorithm._setup_learn(self, total_timesteps, callback, reset_num_timesteps, tb_log_name, progress_bar)
#     421 if reset_num_timesteps or self._last_obs is None:
#     422     assert self.env is not None
# --> 423     self._last_obs = self.env.reset()  # type: ignore[assignment]
#     424     self._last_episode_starts = np.ones((self.env.num_envs,), dtype=bool)
#     425     # Retrieve unnormalized observation for saving into the buffer
#
# File ~/miniconda3/envs/slap_env/lib/python3.11/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:77, in DummyVecEnv.reset(self)
#      75 for env_idx in range(self.num_envs):
#      76     maybe_options = {"options": self._options[env_idx]} if self._options[env_idx] else {}
# ---> 77     obs, self.reset_infos[env_idx] = self.envs[env_idx].reset(seed=self._seeds[env_idx], **maybe_options)
#      78     self._save_obs(env_idx, obs)
#      79 # Seeds and options are only used once
#
# File ~/miniconda3/envs/slap_env/lib/python3.11/site-packages/stable_baselines3/common/monitor.py:83, in Monitor.reset(self, **kwargs)
#      81         raise ValueError(f"Expected you to pass keyword argument {key} into reset")
#      82     self.current_reset_info[key] = value
# ---> 83 return self.env.reset(**kwargs)
#
# TypeError: SimpleGrid.reset() got an unexpected keyword argument 'seed'
